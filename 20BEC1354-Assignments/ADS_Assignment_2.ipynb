# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ***2) Download and load the Dataset***

# %%
data = pd.read_csv("titanic.csv")
data
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    1  22.0      1      0   7.2500        S   Third
# 1           1       1    0  38.0      1      0  71.2833        C   First
# 2           1       3    0  26.0      0      0   7.9250        S   Third
# 3           1       1    0  35.0      1      0  53.1000        S   First
# 4           0       3    1  35.0      0      0   8.0500        S   Third
# ..        ...     ...  ...   ...    ...    ...      ...      ...     ...
# 886         0       2    1  27.0      0      0  13.0000        S  Second
# 887         1       1    0  19.0      0      0  30.0000        S   First
# 888         0       3    0   NaN      1      2  23.4500        S   Third
# 889         1       1    1  26.0      0      0  30.0000        C   First
# 890         0       3    1  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town  alive  alone
# ...

# %% [markdown]
# ***3) Univariate Analysis***

# %%
sns.displot(data.age.value_counts())

# %%
plt.pie(data.embark_town.value_counts(),colors=['green','yellow','blue'],labels=['Southampton','Cherbourg','Queenstown'],autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9248a45db0>,
# ...
#  [Text(-0.7128398214280038, 0.8377704870586524, 'Southampton'),
#   Text(0.4614522559226597, -0.9985298270476893, 'Cherbourg'),
#   Text(1.0595276168013974, -0.29563698894954155, 'Queenstown')],
#  [Text(-0.38882172077891114, 0.4569657202138104, '72.44%'),
#   Text(0.25170123050326887, -0.5446526329351032, '18.90%'),
#   Text(0.577924154618944, -0.16125653942702264, '8.66%')])

# %%
sns.displot(data.fare.value_counts())

# %%
plt.pie(data.alive.value_counts(),colors=['red','blue'],labels=['yes','no'],autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f924b0b7670>,
# ...
#  [Text(-0.3925749350994583, 1.0275626113924428, 'yes'),
#   Text(0.3925750313068116, -1.0275625746369201, 'no')],
#  [Text(-0.21413178278152267, 0.5604886971231505, '61.62%'),
#   Text(0.21413183525826085, -0.5604886770746836, '38.38%')])

# %% [markdown]
# ***3) bivariate analysis***

# %%
plt.plot(data['age'],data['survived'])
plt.xlabel('age')
plt.ylabel('survived')
# Out:
# Text(0, 0.5, 'survived')

# %%
plt.scatter(data['age'],data['fare'])
plt.xlabel('age')
plt.ylabel('fare')
# Out:
# Text(0, 0.5, 'fare')

# %%
plt.scatter(data['pclass'],data['fare'])
plt.xlabel('pclass')
plt.ylabel('fare')
# Out:
# Text(0, 0.5, 'fare')

# %%
plt.plot(data['pclass'],data['fare'])
plt.xlabel('pclass')
plt.ylabel('fare')
# Out:
# Text(0, 0.5, 'fare')

# %% [markdown]
# ***3) multivariate analysis***

# %%
pd.plotting.scatter_matrix(data.loc[:, 'age':'fare'], diagonal="kde",figsize=(20,15))
plt.show()

# %%
ax = data[["age","fare"]].plot(figsize=(20,15))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %% [markdown]
# ***4) descriptive statistics***

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.var()
# Out:
# <ipython-input-49-6bf595b3cfe5>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.var()
# survived         0.236772
# pclass           0.699015
# sex              0.228475
# age            211.019125
# sibsp            1.216043
# parch            0.649728
# fare          2469.436846
# adult_male       0.239723
# alive            0.236772
# alone            0.239723
# dtype: float64

# %%
data.median()
# Out:
# <ipython-input-50-135339ac59ce>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# survived       0.0000
# pclass         3.0000
# sex            1.0000
# age           28.0000
# sibsp          0.0000
# parch          0.0000
# fare          14.4542
# adult_male     1.0000
# alive          0.0000
# alone          1.0000
# dtype: float64

# %%
data.mode()
# Out:
#    survived  pclass  sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3    1  24.0      0      0  8.05        S  Third  man
#
#    adult_male deck  embark_town  alive  alone
# 0        True    C  Southampton      0   True

# %% [markdown]
# ***5) Handling missing values***

# %%
data.isnull().any()
# Out:
# survived       False
# pclass         False
# sex            False
# age             True
# sibsp          False
# parch          False
# fare           False
# embarked        True
# class          False
# who            False
# adult_male     False
# deck            True
# embark_town     True
# alive          False
# alone          False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           687
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data['deck'].fillna(data['deck'].mode(),inplace=True)
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           687
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data['embark_town'].fillna(data['embark_town'].mode(),inplace=True)
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           687
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ***6) finding outliers***

# %%
data_new = pd.read_csv("titanic.csv")
sns.boxplot(data_new.age)
# Out:
# <Axes: >

# %%
perc99=data.age.quantile(0.99)
perc99
# Out:
# 65.87

# %%
data_new = pd.read_csv("titanic.csv")
data_new=data_new[data_new.age<=perc99]
sns.boxplot(data.age)
# Out:
# <Axes: >

# %% [markdown]
# ***7) checking for categorical columns***

# %%
le=LabelEncoder()

# %%
data.alive=le.fit_transform(data.alive)

# %%
data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500        S  Third    man
# 1         1       1    0  38.0      1      0  71.2833        C  First  woman
# 2         1       3    0  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    0  35.0      1      0  53.1000        S  First  woman
# 4         0       3    1  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town  alive  alone
# 0        True    C  Southampton      0      0
# 1       False    C    Cherbourg      1      0
# 2       False  NaN  Southampton      1      1
# 3       False    C  Southampton      1      0
# 4        True  NaN  Southampton      0      1

# %%
data.sex=le.fit_transform(data.sex)

# %%
data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500        S  Third    man
# 1         1       1    0  38.0      1      0  71.2833        C  First  woman
# 2         1       3    0  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    0  35.0      1      0  53.1000        S  First  woman
# 4         0       3    1  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town  alive  alone
# 0        True    C  Southampton      0      0
# 1       False    C    Cherbourg      1      0
# 2       False  NaN  Southampton      1      1
# 3       False    C  Southampton      1      0
# 4        True  NaN  Southampton      0      1

# %%
data.alone=le.fit_transform(data.alone)

# %%
data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500        S  Third    man
# 1         1       1    0  38.0      1      0  71.2833        C  First  woman
# 2         1       3    0  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    0  35.0      1      0  53.1000        S  First  woman
# 4         0       3    1  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town  alive  alone
# 0        True    C  Southampton      0      0
# 1       False    C    Cherbourg      1      0
# 2       False  NaN  Southampton      1      1
# 3       False    C  Southampton      1      0
# 4        True  NaN  Southampton      0      1

# %% [markdown]
# ***8) Splitting data into dependent and independent variables***

# %%
y=data['survived']

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: survived, dtype: int64

# %%
X=data.drop(columns=['survived'],axis=1)

# %%
X.head()
# Out:
#    pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0       3    1  22.0      1      0   7.2500        S  Third    man
# 1       1    0  38.0      1      0  71.2833        C  First  woman
# 2       3    0  26.0      0      0   7.9250        S  Third  woman
# 3       1    0  35.0      1      0  53.1000        S  First  woman
# 4       3    1  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town  alive  alone
# 0        True    C  Southampton      0      0
# 1       False    C    Cherbourg      1      0
# 2       False  NaN  Southampton      1      1
# 3       False    C  Southampton      1      0
# 4        True  NaN  Southampton      0      1

# %% [markdown]
# ***9) Scaling independent variables***

# %%
X=data.drop(columns=['survived','sex','embark_town','deck','class','embarked','who','alive','alone','adult_male'],axis=1)

# %%
name=X.columns

# %%
name
# Out:
# Index(['pclass', 'age', 'sibsp', 'parch', 'fare'], dtype='object')

# %%
scale=MinMaxScaler()

# %%
X_scaled=scale.fit_transform(X)

# %%
X_scaled
# Out:
# array([[1.        , 0.27117366, 0.125     , 0.        , 0.01415106],
#        [0.        , 0.4722292 , 0.125     , 0.        , 0.13913574],
#        [1.        , 0.32143755, 0.        , 0.        , 0.01546857],
#        ...,
#        [1.        ,        nan, 0.125     , 0.33333333, 0.04577135],
#        [0.        , 0.32143755, 0.        , 0.        , 0.0585561 ],
#        [1.        , 0.39683338, 0.        , 0.        , 0.01512699]])

# %%
X=pd.DataFrame(X_scaled,columns=name)

# %%
X
# Out:
#      pclass       age  sibsp     parch      fare
# 0       1.0  0.271174  0.125  0.000000  0.014151
# 1       0.0  0.472229  0.125  0.000000  0.139136
# 2       1.0  0.321438  0.000  0.000000  0.015469
# 3       0.0  0.434531  0.125  0.000000  0.103644
# 4       1.0  0.434531  0.000  0.000000  0.015713
# ..      ...       ...    ...       ...       ...
# 886     0.5  0.334004  0.000  0.000000  0.025374
# 887     0.0  0.233476  0.000  0.000000  0.058556
# 888     1.0       NaN  0.125  0.333333  0.045771
# 889     0.0  0.321438  0.000  0.000000  0.058556
# 890     1.0  0.396833  0.000  0.000000  0.015127
#
# [891 rows x 5 columns]

# %% [markdown]
# ***10) Splitting the data into training and testing***

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.head()
# Out:
#      pclass       age  sibsp     parch      fare
# 140     1.0       NaN  0.000  0.333333  0.029758
# 439     0.5  0.384267  0.000  0.000000  0.020495
# 817     0.5  0.384267  0.125  0.166667  0.072227
# 378     1.0  0.246042  0.000  0.000000  0.007832
# 491     1.0  0.258608  0.000  0.000000  0.014151

# %%
X_test.head()
# Out:
#      pclass       age  sibsp     parch      fare
# 495     1.0       NaN  0.000  0.000000  0.028221
# 648     1.0       NaN  0.000  0.000000  0.014737
# 278     1.0  0.082684  0.500  0.166667  0.056848
# 31      0.0       NaN  0.125  0.000000  0.285990
# 255     1.0  0.359135  0.000  0.333333  0.029758

# %%
y_train
# Out:
# 140    0
# 439    0
# 817    0
# 378    0
# 491    0
#       ..
# 835    1
# 192    1
# 629    0
# 559    1
# 684    0
# Name: survived, Length: 712, dtype: int64

# %%
y_test
# Out:
# 495    0
# 648    0
# 278    0
# 31     1
# 255    1
#       ..
# 780    1
# 837    0
# 215    1
# 833    0
# 372    0
# Name: survived, Length: 179, dtype: int64
